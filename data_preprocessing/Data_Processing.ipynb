# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
initial_data = pd.read_csv('B2AR_initial_file.csv', delimiter=';')
initial_data
# Out:
#      Molecule ChEMBL ID Molecule Name Molecule Max Phase Molecular Weight  \
# 0          CHEMBL399785           NaN               None           369.49
# 1         CHEMBL1083364           NaN               None           470.57
# 2          CHEMBL565547           NaN               None           293.37
# 3         CHEMBL1257914           NaN               None           476.60
# 4          CHEMBL229429           NaN               None           260.27
# ...                 ...           ...                ...              ...
# 1703      CHEMBL4866806           NaN               None           850.03
# 1704      CHEMBL4857743           NaN               None           654.81
# 1705      CHEMBL5200887           NaN               None           790.91
# 1706      CHEMBL4789047           NaN               None           366.51
# 1707      CHEMBL5201712           NaN               None           292.34
#
#      #RO5 Violations AlogP Compound Key  \
# ...

# %%
initial_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1708 entries, 0 to 1707
# Data columns (total 46 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Molecule ChEMBL ID          1708 non-null   object
#  1   Molecule Name               940 non-null    object
#  2   Molecule Max Phase          1708 non-null   object
#  3   Molecular Weight            1708 non-null   object
#  4   #RO5 Violations             1708 non-null   object
#  5   AlogP                       1708 non-null   object
#  6   Compound Key                1708 non-null   object
#  7   Smiles                      1676 non-null   object
#  8   Standard Type               1708 non-null   object
#  9   Standard Relation           819 non-null    object
#  10  Standard Value              821 non-null    float64
#  11  Standard Units              833 non-null    object
#  12  pChEMBL Value               712 non-null    float64
# ...

# %%
data_cleaned = initial_data[["Molecule ChEMBL ID","Smiles","Standard Value"]]
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1708 entries, 0 to 1707
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Molecule ChEMBL ID  1708 non-null   object
#  1   Smiles              1676 non-null   object
#  2   Standard Value      821 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 40.2+ KB

# %%
data_cleaned.dropna(inplace=True)
data_cleaned.reset_index(drop=True, inplace=True)
data_cleaned.info()
data_cleaned.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 821 entries, 0 to 820
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Molecule ChEMBL ID  821 non-null    object
#  1   Smiles              821 non-null    object
#  2   Standard Value      821 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 19.4+ KB
# <ipython-input-5-4ab6b76eaca7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned.dropna(inplace=True)
#        Standard Value
# count    8.210000e+02
# mean     1.260362e+06
# std      3.489987e+07
# min      3.981000e-03
# 25%      1.030000e+01
# 50%      2.500000e+02
# 75%      6.900000e+03
# max      1.000000e+09

# %%
cb2_init = pd.read_csv('CB2_initial_file.csv', delimiter=';')
cb2_init.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6194 entries, 0 to 6193
# Data columns (total 46 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Molecule ChEMBL ID          6194 non-null   object
#  1   Molecule Name               294 non-null    object
#  2   Molecule Max Phase          6194 non-null   object
#  3   Molecular Weight            6194 non-null   float64
#  4   #RO5 Violations             6194 non-null   object
#  5   AlogP                       6194 non-null   object
#  6   Compound Key                6194 non-null   object
#  7   Smiles                      6194 non-null   object
#  8   Standard Type               6194 non-null   object
#  9   Standard Relation           5947 non-null   object
#  10  Standard Value              5948 non-null   float64
#  11  Standard Units              5960 non-null   object
#  12  pChEMBL Value               4894 non-null   float64
# ...

# %%
data_cleaned = cb2_init[["Molecule ChEMBL ID","Smiles","Standard Value"]]
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6194 entries, 0 to 6193
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Molecule ChEMBL ID  6194 non-null   object
#  1   Smiles              6194 non-null   object
#  2   Standard Value      5948 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 145.3+ KB

# %%
data_cleaned.dropna(inplace=True)
data_cleaned.reset_index(drop=True, inplace=True)
data_cleaned.info()
data_cleaned.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5948 entries, 0 to 5947
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Molecule ChEMBL ID  5948 non-null   object
#  1   Smiles              5948 non-null   object
#  2   Standard Value      5948 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 139.5+ KB
# <ipython-input-9-4ab6b76eaca7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned.dropna(inplace=True)
#        Standard Value
# count     5948.000000
# mean      2393.951064
# std       7549.403249
# min          0.010000
# 25%         12.000000
# 50%        158.245000
# 75%       1365.500000
# max     361300.000000

# %%
ckr5_init = pd.read_csv('CKR5_initial_file.csv', delimiter=';')
data_cleaned = ckr5_init[["Molecule ChEMBL ID","Smiles","Standard Value"]]
data_cleaned.dropna(inplace=True)
data_cleaned.reset_index(drop=True, inplace=True)
data_cleaned.info()
data_cleaned.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Molecule ChEMBL ID  215 non-null    object
#  1   Smiles              215 non-null    object
#  2   Standard Value      215 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 5.2+ KB
# <ipython-input-10-8a0625af589d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned.dropna(inplace=True)
#        Standard Value
# count      215.000000
# mean       325.478186
# std       2428.428674
# min          0.100000
# 25%          3.250000
# 50%         11.000000
# 75%         35.500000
# max      30000.000000

# %%
drd1_init = pd.read_csv('DRD1_initial_file.csv', delimiter=';')
data_cleaned = drd1_init[["Molecule ChEMBL ID","Smiles","Standard Value"]]
data_cleaned.dropna(inplace=True)
data_cleaned.reset_index(drop=True, inplace=True)
data_cleaned.info()
data_cleaned.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1703 entries, 0 to 1702
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Molecule ChEMBL ID  1703 non-null   object
#  1   Smiles              1703 non-null   object
#  2   Standard Value      1703 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 40.0+ KB
# <ipython-input-11-934f4bdd8dea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned.dropna(inplace=True)
#        Standard Value
# count     1703.000000
# mean      4266.802663
# std      19781.703077
# min          0.100000
# 25%         35.250000
# 50%        360.000000
# 75%       2126.980000
# max     524810.000000

# %%
#Просмотр файлов с молекулярными дескрипторами
b2ar_mol_des = pd.read_csv('b2ar_mol_des.csv')
cb2_mol_des = pd.read_csv('cb2_mol_des.csv')
ckr5_mol_des = pd.read_csv('ckr5_mol_des.csv')
drd1_mol_des = pd.read_csv('drd1_mol_des.csv')

datasets = [b2ar_mol_des, cb2_mol_des, ckr5_mol_des, drd1_mol_des]
for dataset in datasets:
  dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 821 entries, 0 to 820
# Data columns (total 47 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               821 non-null    object
#  1   Smiles                           821 non-null    object
#  2   Target Name                      821 non-null    object
#  3   Ki                               821 non-null    float64
#  4   exactmw                          821 non-null    float64
#  5   amw                              821 non-null    float64
#  6   lipinskiHBA                      821 non-null    float64
#  7   lipinskiHBD                      821 non-null    float64
#  8   NumRotatableBonds                821 non-null    float64
#  9   NumHBD                           821 non-null    float64
#  10  NumHBA                           821 non-null    float64
#  11  NumHeavyAtoms                    821 non-null    float64
# ...
